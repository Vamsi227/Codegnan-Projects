# %% [markdown]
# <a href="https://colab.research.google.com/github/Vamsi227/Codegnan-Projects/blob/main/JioMart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Needed Data

# %%
# Loading required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# #Identification of URL

# %%
# Identify the URL

URL = 'https://www.jiomart.com/c/groceries/2'
url1 = "https://www.amazon.in/s?k=mobile&ref=nb_sb_noss"
url2 = "https://www.flipkart.com/search?q=moble&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

# %% [markdown]
# #Loading the WebPage in Memory using requests library

# %%
page = requests.get(URL)

# %% [markdown]
# ## Check the Status Code of the Page

# %%
page.status_code
# Out:
# 200

# %%
htmlCode = page.text
soup = BeautifulSoup(htmlCode)

# %% [markdown]
# ## Extracting the HTML Code of the WebPage

# %% [markdown]
# #Checking HTML Code

# %%
htmlCode
# Out:
# '<!doctype html> <html lang="en-US"> <head> <title>JioMart - Best Online Grocery Store for Your Daily Needs</title> <meta charset="utf-8"> <meta name="robots" content="INDEX,FOLLOW"> <meta name="description" content="Buy Grocery Online for your daily necessities from a wide range of Fruits &amp; Vegetables, Daily &amp; Bakery, Beverages, Home Care, etc. Visit JioMart online grocery market." /> <meta name="keywords" content="" /> <meta name="viewport" content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0, user-scalable=0"> <meta name="theme-color" content="#ffffff"/> <link rel="manifest" href="https://www.jiomart.com/manifest.json"> <link rel="icon" type="image/x-icon" href="https://www.jiomart.com/assets/ds2web/jds-icons/favicon.svg" /> <link rel="canonical" href="https://www.jiomart.com/c/groceries/2" /> <meta property="og:site_name" content="JioMart" /> <meta property="og:type" content="website" /> <meta property="og:title" content="JioMart - Best Online Grocery Store for Your Daily Needs" /> <meta property="og:description" content="Buy Grocery Online for your daily necessities from a wide range of Fruits & Vegetables, Daily & Bakery, Beverages, Home Care, etc. Visit JioMart online grocery market." /> <meta property="og:url" content="https://www.jiomart.com/c/groceries/2" /> <meta property="og:image" content="https://www.jiomart.com/assets/global/logo-fb.png" /> <!-- Appple Touch Icons --> <link rel="apple-touch-icon" sizes="48x48" href="https://www.jiomart.com/assets/global/new_toch_jiomart_icon/apple-touch-icon-48x48.png"> <link rel="apple-touch-icon" sizes="72x72" href="https://www.jiomart.com/assets/global/new_toch_jiomart_icon/apple-touch-icon-72x72.png"> <link rel="apple-touch-icon" sizes="128x128" href="https://www.jiomart.com/assets/global/new_toch_jiomart_icon/apple-touch-icon-128x128.png"> <link rel="apple-touch-icon" sizes="256x256" href="https://www.jiomart.com/assets/global/new_toch_jiomart_icon/apple-touch-icon-256x256.png"> <link rel="apple-touch-icon" href="https://www.jiomart.com/assets/global/new_toch_jiomart_icon/apple-touch-icon-48x48.png"> <meta name="google-play-app" content="app-id=com.jpl.jiomart"> <meta name="apple-itunes-app" content="app-id=1522085683"> <link rel="manifest" href="https://www.jiomart.com/manifest.json"> <link type="text/css" rel="stylesheet" href="https://www.jiomart.com/assets/version1731148747/ds2web/css/bootstrap.min.css" /> <link type="text/css" rel="stylesheet" href="https://www.jiomart.com/assets/version1731148747/ds2web/jds-css/ds2_layout.min.css?v=1731384294" /> <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@algolia/autocomplete-theme-classic" /> <link rel="stylesheet" type="text/css" media="all" href="https://www.jiomart.com/assets/version1731148747/ds2web/css/swiper.min.css" /> <link rel="stylesheet" type="text/css" media="all" href="https://www.jiomart.com/assets/version1731148747/ds2web/jds-css/ds2_plp.min.css" /> <script>\nfunction noImageError(element){\n    if(element != undefined && element != null){\n        element.error = null;\n        element.src = window.location.origin+"/assets/global/jiomart-default-image-312x420.png";\n    }   \n}\nlocalStorage.removeItem("controlled_serviceability_data");\ndocument.cookie = "onep=; Max-Age=-99999999;";\nwindow.productExists = [];\nwindow.searchKeyData = {};\nwindow.bannerKeyData = {};\nwindow.dimension18 = null;\nwindow.dimension24 = null;\nwindow.dimension25 = null;\nwindow.dimension26 = null;\nwindow.dimension27 = null;\nwindow.noresult = false;\nwindow.google_location_api_key = \'AIzaSyB5sQgEo5BdIkJTyrebFTXUvd3b7_nN284\';\nwindow.default_pin = \'400020\';\nwindow.default_city = \'Mumbai\';\nwindow.default_state = \'MH\';\nwindow.algolia_filter = false;\nwindow.algolia_app_id = "3YP0HP3WSH";\nwindow.algolia_api_key = "aace3f18430a49e185d2c1111602e4b1";\nwindow.algolia_suffix = \'prod_mart\';\n    let cat_config = \'2,8582,4,3,8583,1524,6047,6\';\n    window.navigation = {\n    ...

# %% [markdown]
# #Wrapping Needed Data

# %%
#Wrapping Single name

name = soup.find('div', attrs={'class' : 'plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80'})
print(name.text)
name = name.text
x = name.strip()
print(x)
# Out:
#  Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )
# Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )

# %%
#Wrapping all Names

res_names = []
names = soup.find_all('div', attrs={'class' : 'plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80'})
print(names)
for i in names:
    x = i.text
    x = x.strip()
    res_names.append(x)
print(res_names)
print(len(res_names))
# Out:
# [<div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 ) </div>, <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> KRIWIN Religious Jewelry Lord Shiv Damru Locket With Puchmukhi Rudraksha Mala Gold-plated Plated Brass Chain </div>, <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Lucky Jewellery 18K Gold Plated Designer Gold color Traditional Ethnic Bangles set For Women For Women (198-J1BG-1724-4-26) </div>, <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Hanaa Women Alloy Laxmi 1 Gram Gold Covering Micro Plated Jewellery Short Kodi Necklace Chain </div>, <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Lucky Jewellery 18K Gold Plated Designer Gold color Traditional Ethnic Bangles set For Women For Women (261-J1BG-1720-4-28) </div>, <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> BR Ornaments New Trendy Silver Chain With White Crystal Studded Silver Plated Chain Alloy Anklet (Pack of 2) </div>, <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> shrinathji imitation Gold plated set of 3pc chain combo. </div>, <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> BR Ornaments A467 Alloy Anklet (Pack of 2) </div>, <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Pinapes Star Multi design Choker Necklace </div>, <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> BR Ornaments A332 Alloy Anklet (Pack of 2) </div>, <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Grishma Traditional Ethnic White Metal Anklet Pair Silver Bracelet For Women Payal </div>, <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> NEXT CREATION Metal (Silver, Black) </div>]
# ['Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )', 'KRIWIN Religious Jewelry Lord Shiv Damru Locket With Puchmukhi Rudraksha Mala Gold-plated Plated Brass Chain', 'Lucky Jewellery 18K Gold Plated Designer Gold color Traditional Ethnic Bangles set For Women For Women (198-J1BG-1724-4-26)', 'Hanaa Women Alloy Laxmi 1 Gram Gold Covering Micro Plated Jewellery Short Kodi Necklace Chain', 'Lucky Jewellery 18K Gold Plated Designer Gold color Traditional Ethnic Bangles set For Women For Women (261-J1BG-1720-4-28)', 'BR Ornaments New Trendy Silver Chain With White Crystal Studded Silver Plated Chain Alloy Anklet (Pack of 2)', 'shrinathji imitation Gold plated set of 3pc chain combo.', 'BR Ornaments A467 Alloy Anklet (Pack of 2)', 'Pinapes Star Multi design Choker Necklace', 'BR Ornaments A332 Alloy Anklet (Pack of 2)', 'Grishma Traditional Ethnic White Metal Anklet Pair Silver Bracelet For Women Payal', 'NEXT CREATION Metal (Silver, Black)']
# 12

# %%
# Wrapping single prices

price = soup.find('span', attrs={'class' : 'jm-heading-xxs jm-mb-xxs'})
print(price.text)
price = price.text
x = price.strip()
print(x)
# Out:
# ₹219.00
# ₹219.00

# %%
#Wrapping all Prices

res_prices = []
prices = soup.find_all('span', attrs={'class' : 'jm-heading-xxs jm-mb-xxs'})
for i in prices:
    x = i.text
    x = x.strip()
    res_prices.append(x)
print(res_prices)
print(len(res_prices))
# Out:
# ['₹219.00', '₹199.00', '₹249.00', '₹603.00', '₹319.00', '₹230.00', '₹440.00', '₹230.00', '₹259.00', '₹294.00', '₹399.00']
# 11

# %%
#Wrapping Details

details = soup.find('div', attrs={'class' : 'plp-card-details-container'})
print(details)
print(details.text)
name = details.text
x = name.strip()
print(x)
main = x.split("    ")
print(main)
main[1] = main[1].split("  ")
print(main)
main[2] = main[2].strip()
print(main)
# Out:
# <div class="plp-card-details-container"> <!-- Product Name --> <div class="plp-card-details-name line-clamp jm-body-xs jm-fc-primary-grey-80"> Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 ) </div> <div class="plp-card-details-price-wrapper"> <div class="plp-card-details-price"> <span class="jm-heading-xxs jm-mb-xxs">₹219.00</span> <span class="jm-body-xxs jm-fc-primary-grey-60 line-through jm-mb-xxs"> ₹2,799.00 </span> </div> <div class="plp-card-details-discount jm-mb-xxs"> <span class="jm-badge"> 92% OFF </span> </div> </div> </div>
#    Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )    ₹219.00  ₹2,799.00     92% OFF
# Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )    ₹219.00  ₹2,799.00     92% OFF
# ['Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )', '₹219.00  ₹2,799.00', ' 92% OFF']
# ['Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )', ['₹219.00', '₹2,799.00'], ' 92% OFF']
# ['Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )', ['₹219.00', '₹2,799.00'], '92% OFF']

# %%
#Wrapping all details
res_details = []
details = soup.find_all('div', attrs={'class' : 'plp-card-details-container'})
for i in details:
  x = i.text
  x = x.strip()
  res_details.append(x)
print(res_details)
main = []
for details in res_details:
  k = details.split("    ")
  if len(k) == 3:
    main.append(k)
print(main)
for i in main:
  i[1] = i[1].split("  ")
  i[2] = i[2].strip()
print(main)
names = []
discounted_price = []
actual_price = []
discount_percent = []
for i in main:
  names.append(i[0])
  discounted_price.append(i[1][0])
  actual_price.append(i[1][1])
  discount_percent.append(i[2])
print(names)
print(len(names))
print(discounted_price)
print(len(discounted_price))
print(actual_price)
print(len(actual_price))
print(discount_percent)
print(len(discount_percent))
final_discounted_prices = []
final_actual_prices = []
for i in discounted_price:
  i = i.replace("₹","")
  i = i.replace(",","")
  final_discounted_prices.append(i)
for i in actual_price:
  i = i.replace("₹","")
  i = i.replace(",","")
  final_actual_prices.append(i)
print(names)
print(final_discounted_prices)
print(final_actual_prices)
print(discount_percent)
# Out:
# ['Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )    ₹219.00  ₹2,799.00     92% OFF', 'KRIWIN Religious Jewelry Lord Shiv Damru Locket With Puchmukhi Rudraksha Mala Gold-plated Plated Brass Chain    ₹199.00  ₹599.00     66% OFF', 'Lucky Jewellery 18K Gold Plated Designer Gold color Traditional Ethnic Bangles set For Women For Women (198-J1BG-1724-4-26)    ₹249.00  ₹2,274.00     89% OFF', 'Hanaa Women Alloy Laxmi 1 Gram Gold Covering Micro Plated Jewellery Short Kodi Necklace Chain    ₹603.00  ₹1,500.00     59% OFF', 'Lucky Jewellery 18K Gold Plated Designer Gold color Traditional Ethnic Bangles set For Women For Women (261-J1BG-1720-4-28)    ₹319.00  ₹2,862.00     88% OFF', 'BR Ornaments New Trendy Silver Chain With White Crystal Studded Silver Plated Chain Alloy Anklet (Pack of 2)    ₹230.00  ₹999.00     76% OFF', 'shrinathji imitation Gold plated set of 3pc chain combo.    ₹440.00  ₹880.00     50% OFF', 'BR Ornaments A467 Alloy Anklet (Pack of 2)    ₹230.00  ₹1,999.00     88% OFF', 'Pinapes Star Multi design Choker Necklace', 'BR Ornaments A332 Alloy Anklet (Pack of 2)    ₹259.00  ₹1,999.00     87% OFF', 'Grishma Traditional Ethnic White Metal Anklet Pair Silver Bracelet For Women Payal    ₹294.00  ₹999.00     70% OFF', 'NEXT CREATION Metal (Silver, Black)    ₹399.00  ₹999.00     60% OFF']
# [['Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )', '₹219.00  ₹2,799.00', ' 92% OFF'], ['KRIWIN Religious Jewelry Lord Shiv Damru Locket With Puchmukhi Rudraksha Mala Gold-plated Plated Brass Chain', '₹199.00  ₹599.00', ' 66% OFF'], ['Lucky Jewellery 18K Gold Plated Designer Gold color Traditional Ethnic Bangles set For Women For Women
# 11
# ['92% OFF', '66% OFF', '89% OFF', '59% OFF', '88% OFF', '76% OFF', '50% OFF', '88% OFF', '87% OFF', '70% OFF', '60% OFF']
# 11
# ['Zeneme Gold-Plated Brass Golden Classic Paisley Shaped Textured Handcrafted Bangles For Women (Set Of 4 )', 'KRIWIN Religious Jewelry Lord Shiv Damru Locket With Puchmukhi Rudraksha Mala Gold-plated Plated Brass Chain', 'Lucky Jewellery 18K Gold Plated Designer Gold color Traditional Ethnic Bangles set For Women For Women (198-J1BG-1724-4-26)', 'Hanaa Women Alloy Laxmi 1 Gram Gold Covering Micro Plated Jewellery Short Kodi Necklace Chain', 'Lucky Jewellery 18K Gold Plated Designer Gold color Traditional Ethnic Bangles set For Women For Women (261-J1BG-1720-4-28)', 'BR Ornaments New Trendy Silver Chain With White Crystal Studded Silver Plated Chain Alloy Anklet (Pack of 2)', 'shrinathji imitation Gold plated set of 3pc chain combo.', 'BR Ornaments A467 Alloy Anklet (Pack of 2)', 'BR Ornaments A332 Alloy Anklet (Pack of 2)', 'Grishma Traditional Ethnic White Metal Anklet Pair Silver Bracelet For Women Payal', 'NEXT CREATION Metal (Silver, Black)']
# ['219.00', '199.00', '249.00', '603.00', '319.00', '230.00', '440.00', '230.00', '259.00', '294.00', '399.00']
# ['2799.00', '599.00', '2274.00', '1500.00', '2862.00', '999.00', '880.00', '1999.00', '1999.00', '999.00', '999.00']
# ['92% OFF', '66% OFF', '89% OFF', '59% OFF', '88% OFF', '76% OFF', '50% OFF', '88% OFF', '87% OFF', '70% OFF', '60% OFF']

# %% [markdown]
# #Applying Pandas

# %%
df = pd.DataFrame({'Product' : names , 'Discounted Price': final_discounted_prices , 'Actual Price' : final_actual_prices , 'Discount Percent' : discount_percent})
df['Discounted Price'] = df['Discounted Price'].astype(float)
df['Actual Price'] = df['Actual Price'].astype(float)
df
# Out:
#                                               Product  Discounted Price  \
# 0   Zeneme Gold-Plated Brass Golden Classic Paisle...             219.0
# 1   KRIWIN Religious Jewelry Lord Shiv Damru Locke...             199.0
# 2   Lucky Jewellery 18K Gold Plated Designer Gold ...             249.0
# 3   Hanaa Women Alloy Laxmi 1 Gram Gold Covering M...             603.0
# 4   Lucky Jewellery 18K Gold Plated Designer Gold ...             319.0
# 5   BR Ornaments New Trendy Silver Chain With Whit...             230.0
# 6   shrinathji imitation Gold plated set of 3pc ch...             440.0
# 7          BR Ornaments A467 Alloy Anklet (Pack of 2)             230.0
# 8          BR Ornaments A332 Alloy Anklet (Pack of 2)             259.0
# 9   Grishma Traditional Ethnic White Metal Anklet ...             294.0
# 10                NEXT CREATION Metal (Silver, Black)             399.0
#
#     Actual Price Discount Percent
# 0         2799.0          92% OFF
# 1          599.0          66% OFF
# 2         2274.0          89% OFF
# 3         1500.0          59% OFF
# 4         2862.0          88% OFF
# 5          999.0          76% OFF
# 6          880.0          50% OFF
# 7         1999.0          88% OFF
# 8         1999.0          87% OFF
# 9          999.0          70% OFF
# 10         999.0          60% OFF

# %% [markdown]
# #Applying Matplotlib

# %%
plt.hist(df['Discounted Price'], bins = 2, color='purple', alpha=0.7)
plt.title('Histogram - Price Variation')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %%
plt.pie(df['Actual Price'], labels=df['Product'], autopct = '%1.2f%%', startangle = 90)
plt.axis('equal')
plt.show()
